# %% [markdown]
# Load Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    "C:\\Users\\aishw\\SAR-Student-Success-Retention\\datasets\\student_success_dataset_30000.csv"
)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (30000, 70)
#      student_id                       department             specialization  \
# 0  STU202600001             Computer Engineering     Full Stack Development
# 1  STU202600002                Civil Engineering  Environmental Engineering
# 2  STU202600003                          AI & ML            Computer Vision
# 3  STU202600004  Electronics & Telecommunication           Embedded Systems
# 4  STU202600005           Mechanical Engineering                    CAD/CAM
#
#   current_year  semester  gender  cgpa  semester_gpa cgpa_trend  \
# 0   Third Year         6    Male  9.00          9.15     Stable
# 1  Second Year         3  Female  8.25          8.31     Stable
# 2   Final Year         7  Female  8.81          8.79     Stable
# 3   First Year         2    Male  8.83          8.69     Stable
# 4   Third Year         6    Male  9.34          9.36     Stable
#
#    backlog_count  ...  stress_score  time_management_score  consistency_score  \
# ...

# %%
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (30000, 70)
#      student_id                       department             specialization  \
# 0  STU202600001             Computer Engineering     Full Stack Development
# 1  STU202600002                Civil Engineering  Environmental Engineering
# 2  STU202600003                          AI & ML            Computer Vision
# 3  STU202600004  Electronics & Telecommunication           Embedded Systems
# 4  STU202600005           Mechanical Engineering                    CAD/CAM
#
#   current_year  semester  gender  cgpa  semester_gpa cgpa_trend  \
# 0   Third Year         6    Male  9.00          9.15     Stable
# 1  Second Year         3  Female  8.25          8.31     Stable
# 2   Final Year         7  Female  8.81          8.79     Stable
# 3   First Year         2    Male  8.83          8.69     Stable
# 4   Third Year         6    Male  9.34          9.36     Stable
#
#    backlog_count  ...  stress_score  time_management_score  consistency_score  \
# ...

# %% [markdown]
# Basic Information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 70 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     30000 non-null  object
#  1   department                     30000 non-null  object
#  2   specialization                 30000 non-null  object
#  3   current_year                   30000 non-null  object
#  4   semester                       30000 non-null  int64
#  5   gender                         30000 non-null  object
#  6   cgpa                           30000 non-null  float64
#  7   semester_gpa                   30000 non-null  float64
#  8   cgpa_trend                     30000 non-null  object
#  9   backlog_count                  30000 non-null  int64
#  10  internal_marks_avg             30000 non-null  float64
#  11  assignment_submission_rate     30000 non-null  float64
# ...

# %% [markdown]
# Missing Values Check

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Duplicate Check

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# Risk Distribution

# %%
print(df["academic_risk_band"].value_counts())

print("\n")

print(df["dropout_risk_band"].value_counts())

print("\n")

print(df["placement_risk_band"].value_counts())
# Out:
# academic_risk_band
# Low         24390
# Medium       3754
# High         1691
# Critical      165
# Name: count, dtype: int64
#
#
# dropout_risk_band
# Low         24157
# Medium       5042
# High          789
# Critical       12
# Name: count, dtype: int64
#
#
# placement_risk_band
# High        14012
# Low          7667
# Medium       7125
# Critical     1196
# Name: count, dtype: int64

# %% [markdown]
# Feature Statistics

# %%
df[
    [
        "cgpa",
        "attendance_percentage",
        "backlog_count",
        "coding_score",
        "stress_score",
        "placement_probability"
    ]
].describe()
# Out:
#                cgpa  attendance_percentage  backlog_count  coding_score  \
# count  30000.000000           30000.000000   30000.000000  30000.000000
# mean       8.314517              86.875339       0.556400     68.920448
# std        0.775800               6.787769       0.994243     15.706217
# min        5.420000              58.330000       0.000000     15.000000
# 25%        7.780000              82.290000       0.000000     58.690000
# 50%        8.360000              87.100000       0.000000     69.920000
# 75%        8.890000              91.840000       1.000000     80.182500
# max       10.000000             100.000000       4.000000    100.000000
#
#        stress_score  placement_probability
# count  30000.000000           30000.000000
# mean      48.235903              47.125413
# std       16.297828              19.469175
# min        5.000000               4.910000
# 25%       36.820000              31.340000
# 50%       46.820000              39.560000
# ...

# %% [markdown]
# Correlation Check

# %%
cols = [
    "cgpa",
    "attendance_percentage",
    "backlog_count",
    "stress_score",
    "coding_score",
    "placement_probability",
    "career_readiness_score"
]

df[cols].corr()
# Out:
#                             cgpa  attendance_percentage  backlog_count  \
# cgpa                    1.000000               0.755820      -0.228428
# attendance_percentage   0.755820               1.000000      -0.205212
# backlog_count          -0.228428              -0.205212       1.000000
# stress_score           -0.240538              -0.254407       0.632477
# coding_score            0.277732               0.248233      -0.063122
# placement_probability   0.349814               0.286216      -0.381479
# career_readiness_score  0.289988               0.253128      -0.074920
#
#                         stress_score  coding_score  placement_probability  \
# cgpa                       -0.240538      0.277732               0.349814
# attendance_percentage      -0.254407      0.248233               0.286216
# backlog_count               0.632477     -0.063122              -0.381479
# stress_score                1.000000     -0.072349              -0.271679
# ...

# %%
df[
    [
        "academic_risk_score",
        "academic_risk_band"
    ]
].sample(20)
# Out:
#        academic_risk_score academic_risk_band
# 25171                 7.96                Low
# 24396                22.13                Low
# 8359                 51.79             Medium
# 1851                 10.60                Low
# 23285                13.79                Low
# 24821                10.77                Low
# 6320                 14.49                Low
# 2410                  7.73                Low
# 8416                  1.99                Low
# 15125                20.19                Low
# 1803                  3.35                Low
# 22994                10.84                Low
# 25580                 8.93                Low
# 7858                 11.29                Low
# 1589                 14.40                Low
# 19577                42.41             Medium
# 19391                25.78                Low
# 14175                22.47                Low
# 15248                50.90             Medium
# ...

# %%
df.groupby("academic_risk_band")["academic_risk_score"].describe()
# Out:
#                       count       mean       std    min     25%    50%  \
# academic_risk_band
# Critical              165.0  83.194000  2.606185  80.00  81.300  82.39
# High                 1691.0  69.683572  5.255303  60.04  65.435  69.81
# Low                 24390.0  16.756690  7.729400   0.00  11.050  15.50
# Medium               3754.0  44.733474  6.855981  35.00  38.480  44.07
#
#                         75%    max
# academic_risk_band
# Critical            84.2300  93.94
# High                73.6350  79.94
# Low                 21.5000  35.00
# Medium              50.0625  59.98

# %%
df.groupby("placement_risk_band")["placement_probability"].describe()
# Out:
#                        count       mean       std    min    25%    50%  \
# placement_risk_band
# Critical              1196.0  16.352993  2.962961   4.91  14.46  17.05
# High                 14012.0  31.530166  4.888206  20.01  28.06  32.06
# Low                   7667.0  73.744952  5.878420  65.00  68.99  72.97
# Medium                7125.0  54.315928  7.671429  40.00  48.04  55.91
#
#                         75%    max
# placement_risk_band
# Critical             18.755  20.00
# High                 35.380  40.00
# Low                  77.625  96.61
# Medium               60.970  65.00

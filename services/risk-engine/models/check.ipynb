# %%
import joblib

model = joblib.load("xgboost_risk_model_v1.pkl")

print(type(model))

if hasattr(model, "steps"):
    print("Pipeline Steps:")
    print(model.named_steps.keys())
else:
    print("Not a Pipeline")
# Out:
# <class 'sklearn.pipeline.Pipeline'>
# Pipeline Steps:
# dict_keys(['preprocessor', 'model'])

# %%
import joblib

pipeline = joblib.load("../notebooks/xgboost_academic_risk_pipeline.pkl")

print(type(pipeline))
print()

print("Pipeline steps:")
print(pipeline.named_steps.keys())

print()

print("Pipeline object:")
print(pipeline)
# Out:
# <class 'sklearn.pipeline.Pipeline'>
#
# Pipeline steps:
# dict_keys(['preprocessor', 'classifier'])
#
# Pipeline object:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['semester', 'cgpa',
#                                                    'semester_gpa',
#                                                    'backlog_count',
#                                                    'internal_marks_avg',
#                                                    'assignment_submission_rate',
#                                                    'lab_performance_score',
#                                                    'project_score',
#                                                    'attendance_percentage',
# ...
